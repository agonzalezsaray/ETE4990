# %% [markdown]
# # Lab 3 - Files

# %% [markdown]
# ## Warm-up
# Using the file Car.txt found in lecture canvas page.
# Part 1:
# Write a function that can open a file. Read its output and save it to a list. (look at lecture notes if you need help)
#
# Part 2:
# Using a function that at minimum takes a list and outputs desired information to a file.  (do not use rstrip for this.
#
# For example
# ```python
# def foo (bar, user_string):
#     if user_string in bar:
#         # save the file here
# ```

# %%
# Code goes here

# %% [markdown]
# # Main Lab
#
# Begin working with your partner on your project. Begin to plan out how you would like your game to feel. Remember this is a text-based game. This can be any game you would like (RPG is the easiest to understand but you can do any type of game please stay away from games like poker or 21 as these tend to be boring to code and hard to expand on, and obviously games that may get you reported by the university)
#
#
# ## Part 1:
# Create class' for your game: You may use  paper and pencil or a planning tool to begin to plan the overall scope of your game. You will be required to turn in a planning tool output next week. (You may use whatever tool you desire)
#
# Create a Flow diagram of your game and how you would like it to play. Keep it simple.
#
# This is due before you leave the class today. It does not need to be your final version.
#
#
# ## Part 2:
# Start writing the code
#
# keep in mind that when you write your code you will need to be loading in your player and tools/items/etc. So plan acordingly.
#
# Here is an example:
# ```python
# class Sharps(object):
#     """Create a sharp weapon"""
#     def __init__(self, name, length, age, damage):
#         """ Initialize name, age, and length damage attributes."""
#         self.name = name
#         self.age = age
#         self.length = length
#         self.damage = damage
#     def do_damage(self, target):
#         target = target - self.damage
#
# class dager(Sharps):
#     """ makes a dager"""
#     def __init__(self, self, name, length, age, damage):
#         """sets up a dagger"""
#         super().__init__(self, name, length, age, damage))
#         self.poision = True
# ```

# %% [markdown]
# ## Part 3:
#
# Create a list of objects that you will be using in your game and store that information in JSON format.
# You do not need to code this but you will need a file with a starting list of all the assets needed to play your game.

# %%
#all classes for game, will read item data from json file created,
import json

class Item:    #create item instance and add type
    def __init__(self, name, type): 
        self.name = name
        self.type = type
    def Equip(): #add item to character or boss
        pass

class Armor(Item):    #child class of item for armor
    def __init__(self, name, damageReduction, description):
        super().__init__(name)
        self.damageReduction = damageReduction
        self.description = description
    def inspect(name):  #reads out armor description for player to read
        print(Armor.description)

class Weapon(Item):    #child class of item for weapon
    def __init__(self, name, maxDamage, description):
        super().__init__(name)
        self.maxDamage = maxDamage
        self.description = description
    def inspect(name):   #reads out weapon description for player to read
        print(Weapon.description)

class Character:
    def __init__(self, name==None, gender==None, health==None, size==None, strength==None, dex==None, archetype==None):
        if name== None or gender==None:
            name = str(input("What is your name?"))
            gender = str(input("Choose your gender. Enter m for male and f for female. This will effect your stats.").lower())
            if gender == 'm':
                self.health = 10
                self.size = 10
                self.strength = 10
                self.dex = 5
            elif gender == 'f':
                self.health = 10
                self.size = 10
                self.strength = 10
                self.dex = 5
            else:
                pass    #make this an early loss, game restarts
        self.Archetype = Character.PickArchetype()
    def PickArchetype():
        i = str(input("Please choose a class of fighter. Enter w for Wizard, f for Fighter, and r for Rogue.").lower())
        if i == 'w':
            return "Wizard"
        elif i == 'f':
            return "Fighter"
        elif i == 'r':
            return "Rogue"
        else:
            print("Please choose one of the three options.")
            Character.PickArchetype()
    def UseAction():
        pass
    def Die():
        pass

class Archetype(Character):
    def __init__(self, archetype, spellcasting, actionCount):
        super().__init__(archetype)
        self.actionCount = actionCount
        self.spellcasting = spellcasting
    def setArmor():
        pass
    def setWeapons():
        pass
    def setSpells():
        if Archetype.spellcasting == True:
            #add cast to list of useable actions
            pass


class Boss(Character):
    def __init__(self, name, description, LegActionCount, spellcasting, health==None, size==None, strength==None, dex==None):
        self.name = name
        self.description = description
        self.LegActionCount = LegActionCount
        self.spellcasting = spellcasting
        self.health = health
        if name == 'one':
            LegActionCount = 2
        if name == 'two':
            LegActionCount = 1
        if name == 'three':
            LegActionCount = 2
    def LegAct():
        pass  

class Actions:
    def __init__(self, name, useable, effect):
        self.name = name
        self.useable = useable
        self.effect = effect
    def listActions():
        pass

class Spells(Actions):
    def __init__(self, name, effect, uses, maxDamage):
        super().__init__(name)
        self.effect = effect
        self.uses = uses
        self.maxDamage = maxDamage
    def cast():
        pass  


with open('all_items.json', 'r') as f:
    all_items = json.load(f)
with open('all_bosses.json', 'r') as p:
    all_bosses = json.load(p)
with open('all_archetypes.json', 'r') as m:
    all_archetypes = json.load(m)
